# %% [markdown]
# <a href="https://colab.research.google.com/github/fabianbele2605/ejemplo/blob/main/grados_celcius_a_fath.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
celsius = np.array([-183, -135, -103, -80, -40, -10, 0, 8, 15, 22, 38, 90, 120, 173, 200], dtype=float)
fahrenheit = np.array([-297.4, -211, -153.4, -112, -40, 14, 32, 46.4, 59, 71.6, 100.4, 194, 248, 343.4, 392], dtype=float)

# %%
#capa = tf.keras.layers.Dense(units=1, input_shape=[1])
#modelo = tf.keras.Sequential([capa])

oculta1 = tf.keras.layers.Dense(units=3, input_shape=[1])
oculta2 = tf.keras.layers.Dense(units=3)
salida = tf.keras.layers.Dense(units=1)
modelo = tf.keras.Sequential([oculta1, oculta2, salida])

# %%
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
print("Comenzando entrenamiento...")
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=False)
print("Modelo entrenado!")
# Out:
# Comenzando entrenamiento...
# Modelo entrenado!

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(historial.history["loss"])

# %%
print("Realizanbdo una prediccion")
input_data = np.array([[10000]])
resultado = modelo.predict(input_data)
print("el resultado es " + str(resultado) + "fahrenheit")
# Out:
# Realizanbdo una prediccion
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# el resultado es [[18031.998]]fahrenheit

# %%
print("Variable interna del modelo")
#print(capa.get_weights())
print(oculta1.get_weights())
print(oculta2.get_weights())
print(salida.get_weights())
# Out:
# Variable interna del modelo
# [array([[-0.08851013, -1.168711  , -0.34882015]], dtype=float32), array([ 4.5108843, -5.444652 , -5.0735717], dtype=float32)]
# [array([[-0.4332844 ,  0.39899182,  0.7574257 ],
#        [ 0.92325217, -0.722351  , -0.1511304 ],
#        [ 0.5696024 , -0.01906848, -1.1345391 ]], dtype=float32), array([-5.186858 , -0.5614328,  5.5339947], dtype=float32)]
# [array([[-1.3069779 ],
#        [-0.09136035],
#        [ 0.5040223 ]], dtype=float32), array([4.9734373], dtype=float32)]
